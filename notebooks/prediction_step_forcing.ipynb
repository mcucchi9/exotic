# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os
import xarray as xr
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
sys.path.append('/home/cucchi/phd/devel/phd/')
RESP_PATH = '/home/cucchi/phd/data/response/lorenz96/rk4/SF_8_1.0_0/'
obs = 'energy_bin_0.1q_0.2q'
force_intensity_delta = 2.0
forcing = 'SF_8_{}_0'.format(force_intensity_delta)

# %%
from lab import analysis
from lab.simulation import forcings

# %% [markdown]
# Average response

# %%
response_p1 = xr.open_dataarray(os.path.join(RESP_PATH, 'response_lorenz96_rk4_{}_SF_8_1.0_0.nc'.format(obs)))
plt.plot(response_p1)

# %% [markdown]
# Susceptibility

# %%
chi = analysis.compute_susceptibility(response_p1.values.squeeze())
plt.plot(chi)
# Out:
# /home/cucchi/miniconda3/envs/l96/lib/python3.7/site-packages/numpy/core/numeric.py:538: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# Predicted Response

# %%
resp_pred = analysis.compute_response(chi, forcings.StepForcing(force_intensity_delta=force_intensity_delta))
plt.plot(resp_pred[0:10000])

# %% [markdown]
# Real Response

# %%
resp_real = xr.open_dataarray('/home/cucchi/phd/data/response/lorenz96/rk4/{f}/response_lorenz96_rk4_{o}_{f}.nc'.format(
    o=obs,
    f=forcing
))
resp_real.plot()

# %% [markdown]
# ### Average

# %%
std_pred = resp_pred[0:10000].std()
sig_digit_pred = -math.floor(math.log10(std_pred))
print('predicted: {} +/- {}'.format(
    round(resp_pred[0:10000].mean(), sig_digit_pred), 
    round(resp_pred[0:10000].std(),sig_digit_pred)
))
std_real = resp_real.std().values
sig_digit_real = -math.floor(math.log10(std_real))
print('real:      {} +/- {}'.format(
    round(float(resp_real.mean().values), sig_digit_real), 
    round(float(resp_real.std().values), sig_digit_real)
))
# Out:
# predicted: -0.015 +/- 0.008
# real:      -0.01 +/- 0.01

# %% [markdown]
# ## Semi-Difference

# %%
RESP_PATH = '/home/cucchi/phd/data/response/lorenz96/rk4/SF_8_-1.0_0/'
response_m1 = xr.open_dataarray(os.path.join(RESP_PATH, 'response_lorenz96_rk4_{}_SF_8_-1.0_0.nc'.format(obs)))
response = (response_p1 - response_m1)/2
chi = analysis.compute_susceptibility(response.values.squeeze())
resp_pred = analysis.compute_response(chi, forcings.StepForcing(force_intensity_delta=force_intensity_delta))
plt.plot(resp_pred[0:10000])

# %%
plt.plot(resp_real[0:10000])
plt.plot(resp_pred[0:10000])

# %% [markdown]
# ### Average

# %%
std_pred = resp_pred[0:10000].std()
sig_digit_pred = -math.floor(math.log10(std_pred))
print('predicted: {} +/- {}'.format(
    round(resp_pred[0:10000].mean(), sig_digit_pred), 
    round(resp_pred[0:10000].std(),sig_digit_pred)
))
std_real = resp_real.std().values
sig_digit_real = -math.floor(math.log10(std_real))
print('real:      {} +/- {}'.format(
    round(float(resp_real.mean().values), sig_digit_real), 
    round(float(resp_real.std().values), sig_digit_real)
))
# Out:
# predicted: -0.016 +/- 0.004
# real:      -0.01 +/- 0.01

# %% [markdown]
# ### Block-Average

# %%
resp_real.rolling(time=1000).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/l96/lib/python3.7/site-packages/xarray/core/dataarray.py in _getitem_coord(self, key)
#     462         try:
# --> 463             var = self._coords[key]
#     464         except KeyError:
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-34a4d011c321> in <module>
# ----> 1 resp_real.rolling(time=1000).mean()
#
# ~/miniconda3/envs/l96/lib/python3.7/site-packages/xarray/core/common.py in rolling(self, dim, min_periods, center, **dim_kwargs)
#     589         dim = either_dict_or_kwargs(dim, dim_kwargs, 'rolling')
#     590         return self._rolling_cls(self, dim, min_periods=min_periods,
# --> 591                                  center=center)
#     592
#     593     def resample(self, indexer=None, skipna=None, closed=None, label=None,
#
# ~/miniconda3/envs/l96/lib/python3.7/site-packages/xarray/core/rolling.py in __init__(self, obj, windows, min_periods, center)
#     153             obj, windows, min_periods=min_periods, center=center)
#     154
# --> 155         self.window_labels = self.obj[self.dim]
#     156
#     157     def __iter__(self):
#
# ~/miniconda3/envs/l96/lib/python3.7/site-packages/xarray/core/dataarray.py in __getitem__(self, key)
#     471     def __getitem__(self, key):
#     472         if isinstance(key, basestring):
# --> 473             return self._getitem_coord(key)
#     474         else:
#     475             # xarray-style array indexing
#
# ~/miniconda3/envs/l96/lib/python3.7/site-packages/xarray/core/dataarray.py in _getitem_coord(self, key)
#     465             dim_sizes = dict(zip(self.dims, self.shape))
#     466             _, key, var = _get_virtual_variable(
# --> 467                 self._coords, key, self._level_coords, dim_sizes)
#     468
#     469         return self._replace_maybe_drop_dims(var, name=key)
#
# ~/miniconda3/envs/l96/lib/python3.7/site-packages/xarray/core/dataset.py in _get_virtual_variable(variables, key, level_vars, dim_sizes)
#      72         ref_var = dim_var.to_index_variable().get_level_variable(ref_name)
#      73     else:
# ---> 74         ref_var = variables[ref_name]
#      75
#      76     if var_name is None:
#
# KeyError: 'time'

# %%
resp_real.rolling(time_step=10).mean().plot()
